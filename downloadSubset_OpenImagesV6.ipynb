# %%
# Strongly pulling from tutorial found here: https://towardsdatascience.com/downloading-openimages-dataset-in-google-drive-using-colab-132502f0dbde

# Package setup
import os, sys
from google.colab import drive

# Mount to my google drive
drive.mount('/content/drive')

# Set current path to desired folder
os.chdir("/content/drive/My Drive/Colab Notebooks/CS230Project/OpenImages")
sys.path.append("/content/drive/My Drive/Colab Notebooks/CS230Project/OpenImages")
# Out:
# Mounted at /content/drive

# %%
# Avoid "aws: not found..." error
# !pip install awscli

# %%
# Download class information and annotations from Google's OpenImages V6
# !wget https://storage.googleapis.com/openimages/2018_04/class-descriptions-boxable.csv
# !wget https://storage.googleapis.com/openimages/2018_04/train/train-annotations-bbox.csv
# !wget https://storage.googleapis.com/openimages/2018_04/validation/validation-annotations-bbox.csv
# !wget https://storage.googleapis.com/openimages/2018_04/test/test-annotations-bbox.csv

# %%
# Implement downloadOI.py from github repository learnopencv, courtesy of Sataya Mallick 

# Insert desired classes, separated by comma, as well as train, test, or validation, depending on desired split
# !python3 downloadOI.py --classes "Cupboard,Salt_and_pepper_shakers,Spice_rack" --mode validation
# Out:
# mkdir: cannot create directory ‘validation’: File exists
# Class 0 : Cupboard
# Class 1 : Salt_and_pepper_shakers
# Class 2 : Spice_rack
# Annotation Count : 92
# Number of images to be downloaded : 66
# 100% 66/66 [01:58<00:00,  1.79s/it]
